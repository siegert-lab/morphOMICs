# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
# Set a new working directory
new_path = '../'
os.chdir(new_path)

from morphomics import protocols, utils
import tomli

# Path to the toml file. Contains the parameters for each protocol
parameters_filepath = "examples/Parameter_files/Morphomics.Parameters_protocols_test.toml"

# read the toml file
with open(parameters_filepath, mode="rb") as _parameter_file:
    parameters = tomli.load(_parameter_file)

# get the protocol
# from already saved protocol
# or initialize a new protocol with parameters
last_instance_path = os.path.join(parameters["path_to_last_instance"], f'last_instance_{parameters["Parameters_ID"]}')
if parameters["load_previous_instance"]:
    protocol = utils.load_obj(last_instance_path)
else:
    protocol = protocols.Protocols(parameters, parameters["Parameters_ID"])
# Out:
# Unless you have specified the file prefix in the succeeding executables,
# this will be the file prefix: Morphomics.PID_test

# %%
script_sequence = parameters['Protocols_test']
print(script_sequence)
# Out:
# ['Input', 'Clean_frame', 'Vectorizations', 'Dim_reductions', 'Save_reduced', 'Mapping']

# %%
perform_this = getattr(protocol, 'Input')
perform_this()
# Out:
# Loading the data from examples/data_test
# Saving dataset in examples/trial_folder/tmd_test/Morphomics.PID_test.TMD-radial_distances
# You are now loading the 3D reconstructions (.swc files) from this folder:
# examples/data_test
#
# Sample filenames:
# examples/data_test/S1/3xKXA/M/BL6_M_KXA1.5W_IBA488_WFA568_CD68647_DAPI_S1_2/Filament_001_Filaments_1_Trace_0032_nl_corrected.swc
# examples/data_test/S1/3xKXA/M/BL6_M_KXA1.5W_IBA488_WFA568_CD68647_DAPI_S1_2/Filament_001_Filaments_1_Trace_0001_nl_corrected.swc
# examples/data_test/S1/3xKXA/M/BL6_M_KXA1.5W_IBA488_WFA568_CD68647_DAPI_S1_2/Filament_001_Filaments_1_Trace_0048_nl_corrected.swc
# examples/data_test/S1/3xKXA/M/BL6_M_KXA1.5W_IBA488_WFA568_CD68647_DAPI_S1_2/Filament_001_Filaments_1_Trace_0019_nl_corrected.swc
# examples/data_test/S1/3xKXA/M/BL6_M_KXA1.5W_IBA488_WFA568_CD68647_DAPI_S1_2/Filament_001_Filaments_1_Trace_0034_nl_corrected.swc
#
# [['S1' '3xKXA' 'M' 'BL6_M_KXA1.5W_IBA488_WFA568_CD68647_DAPI_S1_2'
#   'Filament_001_Filaments_1_Trace_0032_nl_corrected.swc']
#  ['S1' '3xKXA' 'M' 'BL6_M_KXA1.5W_IBA488_WFA568_CD68647_DAPI_S1_2'
#   'Filament_001_Filaments_1_Trace_0001_nl_corrected.swc']
#  ['S1' '3xKXA' 'M' 'BL6_M_KXA1.5W_IBA488_WFA568_CD68647_DAPI_S1_2'
#   'Filament_001_Filaments_1_Trace_0048_nl_corrected.swc']
#  ...
#  ['S1' '2xKXA' 'F' 'BL6_2xKXA_F_WFA488_IBA568_CD68647_S1_3'
#   'Filament_001_Filaments_1_Trace_0020_nl_corrected.swc']
#  ['S1' '2xKXA' 'F' 'BL6_2xKXA_F_WFA488_IBA568_CD68647_S1_3'
#   'Filament_001_Filaments_1_Trace_0025_nl_corrected.swc']
#  ['S1' '2xKXA' 'F' 'BL6_2xKXA_F_WFA488_IBA568_CD68647_S1_3'
#   'Filament_001_Filaments_1_Trace_0033_nl_corrected.swc']]
# Found 961 files...
# Separating DataFrame into Model...
# There are 3 values for the separating condition...
# ...processing 3xKXA
# You have loaded 25% chunk of the data...
# You have loaded 50% chunk of the data...
# You have loaded 75% chunk of the data...
# ...finished loading morphologies and barcodes...
# ! Warning: You have 0 .swc files that did not load. Potentially, empty files. Please check *-FailedFiles
# ...processing 1xKXA
# You have loaded 25% chunk of the data...
# You have loaded 50% chunk of the data...
# You have loaded 75% chunk of the data...
# ...finished loading morphologies and barcodes...
# ! Warning: You have 3 .swc files that did not load. Potentially, empty files. Please check *-FailedFiles
# ...processing 2xKXA
# You have loaded 25% chunk of the data...
# You have loaded 50% chunk of the data...
# You have loaded 75% chunk of the data...
# ...finished loading morphologies and barcodes...
# ! Warning: You have 0 .swc files that did not load. Potentially, empty files. Please check *-FailedFiles
# Input done!

# %%
perform_this = getattr(protocol, 'Clean_frame')
perform_this()
# Out:
# Removing morphologies with barcode size less than 5.00...
# Replacing all instances of `['Saline_4h', 'Saline_48h']` in the `Model` morphoframe column with Adult
# Clean done!
# The cleaned morphoframe is saved in examples/trial_folder/tmd_test_cleaned/Morphomics.PID_test.Cleaned

# %%
parameters['Vectorizations']['vect_method_parameters'] = {'persistence_image': {
                                                          "rescale_lims": False,
                                                          "xlims" : None,
                                                          "ylims" : None,
                                                          "bw_method" : None,
                                                          "barcode_weight" : None,
                                                          "norm_method" : "sum",
                                                          "resolution" : 4,
                                                          "parallel":False
                                                                                },

                                                        }

# %%
perform_this = getattr(protocol, 'Vectorizations')
perform_this()
# Out:
# Computes pi and concatenates the vectors
# Computing persistence images...
# pi done!
#
# The vectors are saved in examples/trial_folder/vectors_test/Morphomics.PID_test.Vectorizations-pi
# Vectorization done!

# %%
perform_this = getattr(protocol, 'Bootstrap')
perform_this()
# Out:
# Bootstrapping with the following parameters:
# bootstrap resolution: Region-Model-Sex
# bootstrap size: 15
# number of bootstraps: 500
# Performing bootstrapping for S1_3xKXA_M...
# There are 136 morphologies to bootstrap...
# Performing subsampling by random selection...
# ...done!
#
# Performing bootstrapping for S1_3xKXA_F...
# There are 152 morphologies to bootstrap...
# Performing subsampling by random selection...
# ...done!
#
# Performing bootstrapping for S1_1xKXA_M...
# There are 211 morphologies to bootstrap...
# Performing subsampling by random selection...
# ...done!
#
# Performing bootstrapping for S1_1xKXA_F...
# There are 160 morphologies to bootstrap...
# Performing subsampling by random selection...
# ...done!
#
# Performing bootstrapping for S1_2xKXA_M...
# There are 159 morphologies to bootstrap...
# Performing subsampling by random selection...
# ...done!
#
# Performing bootstrapping for S1_2xKXA_F...
# There are 136 morphologies to bootstrap...
# Performing subsampling by random selection...
# ...done!
#
# Bootstrap done!
# The bootstraped morphoframe is saved in examples/trial_folder/bootstrap_test/Morphomics.PID_test.Bootstrapped

# %%
parameters['Dim_reductions']['vectors_to_reduce'] = 'pi'
perform_this = getattr(protocol, 'Dim_reductions')
perform_this()
# Out:
# Normalize the vectors
# Reduces the vectors with the following techniques pca_umap
# Running PCA...
# Running UMAP...
# /home/thomas/miniconda3/envs/morphomics/lib/python3.9/site-packages/umap/umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# The reduced vectors and fitted dimreducers are saved in examples/trial_folder/dim_reductions_test/Morphomics.PID_test.DimReductions-pca_umap
# Reducing done!

# %%
perform_this = getattr(protocol, 'Save_reduced')
perform_this()
# Out:
# Preparing .csv file that can be loaded into the morphOMICs dashboard...
# Reduced coordinates splitted and saved!

# %%
protocol.morphoframe['tmd_test']
# Out:
#     Region  Model Sex                                         Animal  \
# 0       S1  3xKXA   M  BL6_M_KXA1.5W_IBA488_WFA568_CD68647_DAPI_S1_2
# 1       S1  3xKXA   M  BL6_M_KXA1.5W_IBA488_WFA568_CD68647_DAPI_S1_2
# 2       S1  3xKXA   M  BL6_M_KXA1.5W_IBA488_WFA568_CD68647_DAPI_S1_2
# 3       S1  3xKXA   M  BL6_M_KXA1.5W_IBA488_WFA568_CD68647_DAPI_S1_2
# 4       S1  3xKXA   M  BL6_M_KXA1.5W_IBA488_WFA568_CD68647_DAPI_S1_2
# ..     ...    ...  ..                                            ...
# 949     S1  2xKXA   F         BL6_2xKXA_F_WFA488_IBA568_CD68647_S1_3
# 950     S1  2xKXA   F         BL6_2xKXA_F_WFA488_IBA568_CD68647_S1_3
# 951     S1  2xKXA   F         BL6_2xKXA_F_WFA488_IBA568_CD68647_S1_3
# 952     S1  2xKXA   F         BL6_2xKXA_F_WFA488_IBA568_CD68647_S1_3
# 953     S1  2xKXA   F         BL6_2xKXA_F_WFA488_IBA568_CD68647_S1_3
#
#                                             _file_name  \
# 0    Filament_001_Filaments_1_Trace_0032_nl_correct...
# 1    Filament_001_Filaments_1_Trace_0001_nl_correct...
# 2    Filament_001_Filaments_1_Trace_0048_nl_correct...
# 3    Filament_001_Filaments_1_Trace_0019_nl_correct...
# 4    Filament_001_Filaments_1_Trace_0034_nl_correct...
# ..                                                 ...
# 949  Filament_001_Filaments_1_Trace_0016_nl_correct...
# 950  Filament_001_Filaments_1_Trace_0029_nl_correct...
# 951  Filament_001_Filaments_1_Trace_0020_nl_correct...
# 952  Filament_001_Filaments_1_Trace_0025_nl_correct...
# 953  Filament_001_Filaments_1_Trace_0033_nl_correct...
#
#                                           path_to_file  \
# 0    examples/data_test/S1/3xKXA/M/BL6_M_KXA1.5W_IB...
# 1    examples/data_test/S1/3xKXA/M/BL6_M_KXA1.5W_IB...
# 2    examples/data_test/S1/3xKXA/M/BL6_M_KXA1.5W_IB...
# 3    examples/data_test/S1/3xKXA/M/BL6_M_KXA1.5W_IB...
# 4    examples/data_test/S1/3xKXA/M/BL6_M_KXA1.5W_IB...
# ..                                                 ...
# 949  examples/data_test/S1/2xKXA/F/BL6_2xKXA_F_WFA4...
# 950  examples/data_test/S1/2xKXA/F/BL6_2xKXA_F_WFA4...
# 951  examples/data_test/S1/2xKXA/F/BL6_2xKXA_F_WFA4...
# 952  examples/data_test/S1/2xKXA/F/BL6_2xKXA_F_WFA4...
# 953  examples/data_test/S1/2xKXA/F/BL6_2xKXA_F_WFA4...
#
#                                                   tree  \
# 0    <tmd.Neuron.Neuron.Neuron object at 0x79cad4a6...
# 1    <tmd.Neuron.Neuron.Neuron object at 0x79cad4a6...
# 2    <tmd.Neuron.Neuron.Neuron object at 0x79cad4a6...
# 3    <tmd.Neuron.Neuron.Neuron object at 0x79cad4a6...
# 4    <tmd.Neuron.Neuron.Neuron object at 0x79cad4a6...
# ..                                                 ...
# 949  <tmd.Neuron.Neuron.Neuron object at 0x79cad1d3...
# 950  <tmd.Neuron.Neuron.Neuron object at 0x79cad1d3...
# 951  <tmd.Neuron.Neuron.Neuron object at 0x79cad1d3...
# 952  <tmd.Neuron.Neuron.Neuron object at 0x79cad1d3...
# 953  <tmd.Neuron.Neuron.Neuron object at 0x79cad1d3...
#
#                                               barcodes  Barcode_length  \
# 0    [[32.88112258911133, 38.60457992553711], [34.0...              78
# 1    [[58.738914489746094, 62.501365661621094], [56...              56
# 2    [[16.02642059326172, 16.912622451782227], [19....              19
# 3    [[20.95928955078125, 23.62989616394043], [20.4...              30
# 4    [[22.07423973083496, 21.605470657348633], [19....              57
# ..                                                 ...             ...
# 949  [[36.426021575927734, 32.92659378051758], [28....              50
# 950  [[41.91841125488281, 46.87718200683594], [47.6...              38
# 951  [[24.02989959716797, 20.584012985229492], [18....              38
# 952  [[21.591903686523438, 18.711814880371094], [36...              74
# 953  [[7.878785133361816, 5.904836177825928], [11.4...              39
#
#                                                     pi  \
# 0    [0.09400483006384758, 1.5609058450791857e-05, ...
# 1    [0.2730364626765845, 1.3262015515019332e-06, 4...
# 2    [0.3731421152579107, 1.7773194249966753e-05, 5...
# 3    [0.09441607375156558, 1.3163367980882567e-05, ...
# 4    [0.3227962221996428, 6.318068462345316e-06, 1....
# ..                                                 ...
# 949  [0.058726007706909, 0.00023876956784934855, 1....
# 950  [0.1333777064231568, 1.5899727257782162e-05, 6...
# 951  [0.578983612257186, 2.3437783108802415e-06, 4....
# 952  [0.1990148954550892, 3.9952067932314035e-08, 1...
# 953  [0.11633706134670092, 1.9140233927842433e-07, ...
#
#                                pca_umap
# 0      [21.015387, 7.8562946, 3.292992]
# 1    [3.0667992, -5.0535502, 11.815356]
# 2    [-4.386854, -1.6729397, 3.5980036]
# 3     [-7.935733, 4.2423944, 1.2090698]
# 4      [4.687487, -7.200467, 11.409987]
# ..                                  ...
# 949   [19.072357, 7.5300493, 1.1112393]
# 950    [21.99361, 3.5124938, 5.6651278]
# 951    [-7.87081, 1.3182032, 7.8397465]
# 952     [22.490751, 4.351348, 9.487813]
# 953   [4.950564, 1.6880202, -4.9980297]
#
# [954 rows x 11 columns]

# %%
protocol.morphoframe['bootstrap_frame']
# Out:
#      Region  Model Sex                                 Bootstrapped index  \
# 0        S1  3xKXA   M  Index([10, 22, 40, 44, 50, 55, 57, 65, 75, 77,...
# 1        S1  3xKXA   M  Index([2, 17, 23, 65, 66, 69, 70, 73, 76, 86, ...
# 2        S1  3xKXA   M  Index([7, 20, 25, 36, 38, 60, 61, 73, 89, 100,...
# 3        S1  3xKXA   M  Index([17, 22, 28, 31, 33, 39, 54, 62, 64, 70,...
# 4        S1  3xKXA   M  Index([11, 31, 33, 37, 40, 44, 54, 55, 58, 61,...
# ...     ...    ...  ..                                                ...
# 2995     S1  2xKXA   F  Index([818, 820, 836, 854, 861, 872, 884, 901,...
# 2996     S1  2xKXA   F  Index([832, 838, 840, 857, 863, 869, 876, 911,...
# 2997     S1  2xKXA   F  Index([818, 827, 830, 836, 837, 844, 848, 849,...
# 2998     S1  2xKXA   F  Index([823, 833, 845, 853, 863, 882, 885, 888,...
# 2999     S1  2xKXA   F  Index([820, 821, 826, 829, 832, 838, 850, 860,...
#
#                                                barcodes
# 0     [[39.74898910522461, 37.70207595825195], [40.0...
# 1     [[16.02642059326172, 16.912622451782227], [19....
# 2     [[17.880802154541016, 16.355375289916992], [11...
# 3     [[24.34511947631836, 25.48996353149414], [22.6...
# 4     [[39.16337203979492, 37.75926971435547], [37.7...
# ...                                                 ...
# 2995  [[64.37461853027344, 63.90519714355469], [56.1...
# 2996  [[40.6446418762207, 41.8763427734375], [39.238...
# 2997  [[64.37461853027344, 63.90519714355469], [56.1...
# 2998  [[24.567617416381836, 23.344362258911133], [31...
# 2999  [[39.79297637939453, 38.1237907409668], [31.15...
#
# [3000 rows x 5 columns]

# %%
protocol.metadata['bootstrap_info']
# Out:
#      Region  Model Sex
# 0        S1  3xKXA   M
# 1        S1  3xKXA   M
# 2        S1  3xKXA   M
# 3        S1  3xKXA   M
# 4        S1  3xKXA   M
# ...     ...    ...  ..
# 2995     S1  2xKXA   F
# 2996     S1  2xKXA   F
# 2997     S1  2xKXA   F
# 2998     S1  2xKXA   F
# 2999     S1  2xKXA   F
#
# [3000 rows x 3 columns]

# %%
protocol.parameters['Plotting']={"ReductionInfo_filepath" : ["infer",],

                                "morphoframe_name" : "tmd_test",
                                "coordinate_key" : "pca_umap",
                                "label_conditions" : ["Region", "Model", "Sex",],

                                #"morphoinfo_key" : "tmd_info",
                                
                                "coordinate_filepath" : [], 
                                "morphoInfo_filepath" : [],
                                "colormap_filepath" : [
                                    "examples/Parameter_files/colormap.1.csv",],
                                "label_prefixes" : ["Sample"],
                                


                                "Substitutions" : [],

                                "show_plot" : True,
                                "coordinate_axisnames" : "UMAP",
                                "save_data" : True,
                                "save_folderpath" : "examples/trial_folder/plot",
                                "save_filename" : 0
                                }
perform_this = getattr(protocol, 'Plotting')
perform_this()
# Out:
# Creating the interactive plot...
# infer
# The following file was not found: infer
# Inferring the morpho_infoframe and manifold coordinates from Protocol class.
# No substitutions for coordinate set 1...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 25
#       1 protocol.parameters['Plotting']={"ReductionInfo_filepath" : ["infer",],
#       2                                 "coordinate_axisnames" : "UMAP",
#       3                                 "label_conditions" : [
#    (...)
#      22                                 "save_filename" : 0
#      23                                 }
#      24 perform_this = getattr(protocol, 'Plotting')
# ---> 25 perform_this()
#
# File ~/Desktop/morphOMICs/morphomics/protocols.py:971, in Protocols.Plotting(self)
#     968 except:
#     969     print("No substitutions for coordinate set %d..."%(_idx+1))
# --> 971 morphomics.plotting.scatterplot_3D_conditions(
#     972     coordinates, morpho_info, conditions, colormap, params["label_prefixes"][_idx]
#     973 )
#     975 # the first file is considered as the main spectrum
#     976 if _idx == 0:
#
# File ~/Desktop/morphOMICs/morphomics/Analysis/plotting.py:820, in scatterplot_3D_conditions(_coordinates, _morpho_info, _conditions, _colormap, _label_prefix)
#     815     raise ValueError(
#     816         "`Color_type` must either be `solid`, `gradient_mod` or `gradient_pre`"
#     817     )
#     819 if len(time_inds) > 0:
# --> 820     scatterplot_3D(
#     821         _coordinates[time_inds],
#     822         2,
#     823         _c,
#     824         "%s%s" % (_label_prefix, "_".join(conds.values)),
#     825         0.7,
#     826     )
#
# File ~/Desktop/morphOMICs/morphomics/Analysis/plotting.py:720, in scatterplot_3D(_coordinates, _size, _color, _description, _alpha)
#     690 def scatterplot_3D(_coordinates, _size, _color, _description, _alpha):
#     691     '''The `scatterplot_3D` function creates a 3D scatter plot using ipyvolume with specified
#     692         coordinates, size, color, description, and transparency.
#     693
#    (...)
#     717
#     718         '''
#     719     ipv.scatter(
# --> 720         _coordinates[:, 0],
#     721         _coordinates[:, 1],
#     722         _coordinates[:, 2],
#     723         size=_size,
#     724         color=_color,
#     725         marker="sphere",
#     726         description=_description,
#     727         alpha=_alpha,
#     728     )
#
# File ~/miniconda3/envs/morphomics/lib/python3.9/site-packages/pandas/core/series.py:1144, in Series.__getitem__(self, key)
#    1141     key = np.asarray(key, dtype=bool)
#    1142     return self._get_rows_with_mask(key)
# -> 1144 return self._get_with(key)
#
# File ~/miniconda3/envs/morphomics/lib/python3.9/site-packages/pandas/core/series.py:1154, in Series._get_with(self, key)
#    1149     raise TypeError(
#    1150         "Indexing a Series with DataFrame is not "
#    1151         "supported, use the appropriate DataFrame column"
#    1152     )
#    1153 elif isinstance(key, tuple):
# -> 1154     return self._get_values_tuple(key)
#    1156 elif not is_list_like(key):
#    1157     # e.g. scalars that aren't recognized by lib.is_scalar, GH#32684
#    1158     return self.loc[key]
#
# File ~/miniconda3/envs/morphomics/lib/python3.9/site-packages/pandas/core/series.py:1198, in Series._get_values_tuple(self, key)
#    1195     return result
#    1197 if not isinstance(self.index, MultiIndex):
# -> 1198     raise KeyError("key of type tuple not found and not a MultiIndex")
#    1200 # If key is contained, would have returned by now
#    1201 indexer, new_index = self.index.get_loc_level(key)
#
# KeyError: 'key of type tuple not found and not a MultiIndex'

# %%
perform_this = getattr(protocol, 'Mapping')
perform_this()

# %%
protocol.morphoframe

# %%
protocol.metadata

# %%
script_sequence = parameters["Protocols"]
for sequence in script_sequence:
    print("Doing %s..."%sequence)
    perform_this = getattr(protocol, sequence)
    perform_this()
if parameters["save_last_instance"]:
    utils.save_obj(protocol, last_instance_path)
